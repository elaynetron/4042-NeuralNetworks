# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import os
#os.chdir('/content/drive/MyDrive/Real_data')

# %% [markdown]
# ## Import Libraries

# %%
import os
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pickle5
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load pickle file

# %%
dir_name = './processed/'

def load_pickle(filename):
    with open(dir_name + filename + '.pkl', 'rb') as f:
        return pickle5.load(f)

# %% [markdown]
# ## Initialisation - based on paper

# %%
img_size = 227
num_channels = 3
batch_size = 50
width, height = 256, 256
cropped_width, cropped_height = 227, 227
num_classes = 1

seed = 10
np.random.seed(seed)
tf.random.set_seed(seed)

# Learning rate
lr = 1e-3

# %% [markdown]
# From the paper, it said to drop the learning rate to 1e^-4 when epochs reach 10k.
# (1e^-3 - 1e^-4) is a drop of 10%, hence we use 0.1

# %%
def step_decay(epoch):
    init_lrate = 1e-3
    drop = 0.1
    epochs_drop = 10000
    lrate = init_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

weight_init = keras.initializers.TruncatedNormal(mean=0.0,stddev=0.01,seed=seed)
#bias_init = tf.keras.initializers.Constant(value=0.1)
sgd = keras.optimizers.SGD(learning_rate=lr,momentum=0.0)
loss_func = keras.losses.BinaryCrossentropy()
lrate = keras.callbacks.LearningRateScheduler(step_decay)

# %% [markdown]
# ## Width

# %% [markdown]
# Widths:
# - conv1: 48, 96, 192
# - conv2: 128, 256, 512
# - conv3: 192, 384, 768
# - fc: 256, 512, 1024

# %%
conv1_width = 48
conv2_width = 256
conv3_width = 384
fc_width = 512

# %% [markdown]
# ## Load and process data

# %%
to_pickle = [['train', 'test']]
for i in range(5):
  to_pickle.append(["fold_%s_train_sub"%i, "fold_%s_val"%i])

# %%
one_csv = to_pickle[0] # change
train_pickle = load_pickle(one_csv[0])
val_pickle = load_pickle(one_csv[1])

X_train = np.array(train_pickle['images'])    
y_train = np.array(train_pickle['genders'])

X_val = np.array(val_pickle['images'])
y_val = np.array(val_pickle['genders'])

# %% [markdown]
# Check that the image size is as described in the paper (256x256)

# %%
img = X_train[50,:,:,:]
plt.imshow(img)

# %% [markdown]
# Crop image and check that image is now cropped as described in paper (227x227)

# %%
left = int((width - cropped_width)/2)
right = int((width + cropped_width)/2)
top = int((height - cropped_height)/2)
bottom = int((height + cropped_height)/2)

X_train = X_train[:,left:right,top:bottom,:]
X_val = X_val[:,left:right,top:bottom,:]

img = X_train[50,:,:,:]
plt.imshow(img)

# %% [markdown]
# ## Model - based on paper

# %%
model = keras.models.Sequential()
# First convolution layer - 7x7 kernel, 4 strides, valid padding, relu
model.add(keras.layers.Conv2D(conv1_width, (7,7),input_shape = (cropped_width, cropped_height, num_channels), strides = 4,
                                  padding ='valid',activation = 'relu',kernel_initializer = weight_init))
# Max pooling - 3x3 kernel, 2 strides, channel last by default
model.add(keras.layers.MaxPool2D(pool_size = (3,3), strides = 2, padding = 'same'))
# Output - 96x28x28
model.add(keras.layers.Lambda(lambda x: tf.nn.local_response_normalization(input=x, alpha=0.0001, beta=0.75)))

# Second convolution layer - 5x5 kernel, relu, same padding
model.add(keras.layers.Conv2D(conv2_width, (5,5), padding = 'same',activation = 'relu', kernel_initializer = weight_init))
# Max pooling - 3x3 kernel, 2 strides, channel last by default
model.add(keras.layers.MaxPool2D(pool_size = (3, 3), strides = 2,padding = 'same'))
#Output - 14x14
model.add(keras.layers.Lambda(lambda x: tf.nn.local_response_normalization(input=x, alpha=0.0001, beta=0.75)))\

# Last convolution layer - 3x3 kernel, relu, same padding
model.add(keras.layers.Conv2D(conv3_width, (3,3),padding = 'same',activation = 'relu',kernel_initializer = weight_init))
# Max pooling - 3x3 kernel, 2 strides, channel last by default
model.add(keras.layers.MaxPool2D(pool_size = (3,3), strides=2, padding = 'same'))

# Flatten
model.add(keras.layers.Flatten())
# 2 Fully Connected Layers
# FC1:
model.add(keras.layers.Dense(fc_width, activation = "relu", kernel_initializer = weight_init))
# Dropout
model.add(keras.layers.Dropout(0.5))
# FC2:
model.add(keras.layers.Dense(fc_width, activation = 'relu', kernel_initializer = weight_init))
#Dropout
model.add(keras.layers.Dropout(0.5))
#FC3 - Third, fully connected layer which maps to the final classes for age or gender
model.add(keras.layers.Dense(num_classes, activation = 'sigmoid', kernel_initializer = weight_init))

model.compile(loss=loss_func,optimizer=sgd,metrics=['accuracy'])

dir_name = './width_model/'
if not os.path.isdir(dir_name):
  os.mkdir(dir_name)

checkpoint = keras.callbacks.ModelCheckpoint(dir_name + one_csv[0][:6] + '.ckpt', monitor='val_accuracy', 
                                                 verbose=1, mode='max', save_best_only = True)
csv_logger = keras.callbacks.CSVLogger(dir_name + one_csv[0][:6] + '.csv')
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',patience=4)
callbacks = [lrate,checkpoint,csv_logger,early_stopping]

num_epochs = 50
#if one_csv[0][:4] == 'fold':
#  num_epochs = 500

model.summary()
results = model.fit(X_train, y_train,
                        batch_size = batch_size,
                        epochs = num_epochs,
                        verbose=2,
                        callbacks=callbacks,
                        validation_data = (X_val,y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 56, 56, 48)        7104
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 48)       0
#  )
#
#  lambda (Lambda)             (None, 28, 28, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 256)       307456
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  lambda_1 (Lambda)           (None, 14, 14, 256)       0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 384)       885120
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 384)        0
#  2D)
#
#  flatten (Flatten)           (None, 18816)             0
#
#  dense (Dense)               (None, 512)               9634304
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 11,097,153
# Trainable params: 11,097,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#
# Epoch 00001: val_accuracy improved from -inf to 0.52262, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 139s - loss: 0.6915 - accuracy: 0.5352 - val_loss: 0.6922 - val_accuracy: 0.5226 - lr: 0.0010 - 139s/epoch - 495ms/step
# Epoch 2/50
#
# Epoch 00002: val_accuracy did not improve from 0.52262
# 280/280 - 136s - loss: 0.6904 - accuracy: 0.5388 - val_loss: 0.6907 - val_accuracy: 0.5226 - lr: 0.0010 - 136s/epoch - 487ms/step
# Epoch 3/50
#
# Epoch 00003: val_accuracy did not improve from 0.52262
# 280/280 - 139s - loss: 0.6888 - accuracy: 0.5424 - val_loss: 0.6897 - val_accuracy: 0.5226 - lr: 0.0010 - 139s/epoch - 498ms/step
# Epoch 4/50
#
# Epoch 00004: val_accuracy improved from 0.52262 to 0.52892, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 139s - loss: 0.6868 - accuracy: 0.5480 - val_loss: 0.6864 - val_accuracy: 0.5289 - lr: 0.0010 - 139s/epoch - 497ms/step
# Epoch 5/50
#
# Epoch 00005: val_accuracy improved from 0.52892 to 0.53007, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 140s - loss: 0.6841 - accuracy: 0.5614 - val_loss: 0.6832 - val_accuracy: 0.5301 - lr: 0.0010 - 140s/epoch - 501ms/step
# Epoch 6/50
#
# Epoch 00006: val_accuracy improved from 0.53007 to 0.59135, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 151s - loss: 0.6801 - accuracy: 0.5693 - val_loss: 0.6755 - val_accuracy: 0.5914 - lr: 0.0010 - 151s/epoch - 538ms/step
# Epoch 7/50
#
# Epoch 00007: val_accuracy improved from 0.59135 to 0.60997, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 156s - loss: 0.6730 - accuracy: 0.5898 - val_loss: 0.6670 - val_accuracy: 0.6100 - lr: 0.0010 - 156s/epoch - 557ms/step
# Epoch 8/50
#
# Epoch 00008: val_accuracy improved from 0.60997 to 0.61970, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 143s - loss: 0.6653 - accuracy: 0.6072 - val_loss: 0.6553 - val_accuracy: 0.6197 - lr: 0.0010 - 143s/epoch - 510ms/step
# Epoch 9/50
#
# Epoch 00009: val_accuracy improved from 0.61970 to 0.62428, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 142s - loss: 0.6555 - accuracy: 0.6136 - val_loss: 0.6478 - val_accuracy: 0.6243 - lr: 0.0010 - 142s/epoch - 507ms/step
# Epoch 10/50
#
# Epoch 00010: val_accuracy improved from 0.62428 to 0.63431, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 140s - loss: 0.6470 - accuracy: 0.6244 - val_loss: 0.6363 - val_accuracy: 0.6343 - lr: 0.0010 - 140s/epoch - 500ms/step
# Epoch 11/50
#
# Epoch 00011: val_accuracy did not improve from 0.63431
# 280/280 - 142s - loss: 0.6379 - accuracy: 0.6385 - val_loss: 0.6627 - val_accuracy: 0.5971 - lr: 0.0010 - 142s/epoch - 506ms/step
# Epoch 12/50
#
# Epoch 00012: val_accuracy improved from 0.63431 to 0.65693, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 141s - loss: 0.6269 - accuracy: 0.6531 - val_loss: 0.6143 - val_accuracy: 0.6569 - lr: 0.0010 - 141s/epoch - 505ms/step
# Epoch 13/50
#
# Epoch 00013: val_accuracy did not improve from 0.65693
# 280/280 - 138s - loss: 0.6179 - accuracy: 0.6552 - val_loss: 0.6474 - val_accuracy: 0.6208 - lr: 0.0010 - 138s/epoch - 492ms/step
# Epoch 14/50
#
# Epoch 00014: val_accuracy improved from 0.65693 to 0.67583, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 140s - loss: 0.6080 - accuracy: 0.6676 - val_loss: 0.5909 - val_accuracy: 0.6758 - lr: 0.0010 - 140s/epoch - 501ms/step
# Epoch 15/50
#
# Epoch 00015: val_accuracy improved from 0.67583 to 0.68328, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 139s - loss: 0.6001 - accuracy: 0.6749 - val_loss: 0.5879 - val_accuracy: 0.6833 - lr: 0.0010 - 139s/epoch - 497ms/step
# Epoch 16/50
#
# Epoch 00016: val_accuracy improved from 0.68328 to 0.68442, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 143s - loss: 0.5918 - accuracy: 0.6819 - val_loss: 0.5871 - val_accuracy: 0.6844 - lr: 0.0010 - 143s/epoch - 510ms/step
# Epoch 17/50
#
# Epoch 00017: val_accuracy improved from 0.68442 to 0.69187, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 141s - loss: 0.5860 - accuracy: 0.6860 - val_loss: 0.5725 - val_accuracy: 0.6919 - lr: 0.0010 - 141s/epoch - 504ms/step
# Epoch 18/50
#
# Epoch 00018: val_accuracy improved from 0.69187 to 0.69903, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 142s - loss: 0.5782 - accuracy: 0.6941 - val_loss: 0.5708 - val_accuracy: 0.6990 - lr: 0.0010 - 142s/epoch - 507ms/step
# Epoch 19/50
#
# Epoch 00019: val_accuracy improved from 0.69903 to 0.69960, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 138s - loss: 0.5724 - accuracy: 0.6999 - val_loss: 0.5573 - val_accuracy: 0.6996 - lr: 0.0010 - 138s/epoch - 492ms/step
# Epoch 20/50
#
# Epoch 00020: val_accuracy improved from 0.69960 to 0.70962, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 138s - loss: 0.5649 - accuracy: 0.7065 - val_loss: 0.5581 - val_accuracy: 0.7096 - lr: 0.0010 - 138s/epoch - 492ms/step
# Epoch 21/50
#
# Epoch 00021: val_accuracy improved from 0.70962 to 0.71907, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 141s - loss: 0.5557 - accuracy: 0.7157 - val_loss: 0.5428 - val_accuracy: 0.7191 - lr: 0.0010 - 141s/epoch - 505ms/step
# Epoch 22/50
#
# Epoch 00022: val_accuracy did not improve from 0.71907
# 280/280 - 140s - loss: 0.5482 - accuracy: 0.7225 - val_loss: 0.5595 - val_accuracy: 0.7070 - lr: 0.0010 - 140s/epoch - 498ms/step
# Epoch 23/50
#
# Epoch 00023: val_accuracy did not improve from 0.71907
# 280/280 - 139s - loss: 0.5404 - accuracy: 0.7298 - val_loss: 0.5493 - val_accuracy: 0.7179 - lr: 0.0010 - 139s/epoch - 498ms/step
# Epoch 24/50
#
# Epoch 00024: val_accuracy improved from 0.71907 to 0.73797, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 138s - loss: 0.5301 - accuracy: 0.7313 - val_loss: 0.5168 - val_accuracy: 0.7380 - lr: 0.0010 - 138s/epoch - 493ms/step
# Epoch 25/50
#
# Epoch 00025: val_accuracy did not improve from 0.73797
# 280/280 - 140s - loss: 0.5194 - accuracy: 0.7448 - val_loss: 0.5241 - val_accuracy: 0.7342 - lr: 0.0010 - 140s/epoch - 502ms/step
# Epoch 26/50
#
# Epoch 00026: val_accuracy improved from 0.73797 to 0.76031, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 141s - loss: 0.5083 - accuracy: 0.7513 - val_loss: 0.4947 - val_accuracy: 0.7603 - lr: 0.0010 - 141s/epoch - 504ms/step
# Epoch 27/50
#
# Epoch 00027: val_accuracy did not improve from 0.76031
# 280/280 - 141s - loss: 0.4982 - accuracy: 0.7592 - val_loss: 0.5588 - val_accuracy: 0.7090 - lr: 0.0010 - 141s/epoch - 503ms/step
# Epoch 28/50
#
# Epoch 00028: val_accuracy did not improve from 0.76031
# 280/280 - 140s - loss: 0.4819 - accuracy: 0.7723 - val_loss: 0.5405 - val_accuracy: 0.7228 - lr: 0.0010 - 140s/epoch - 501ms/step
# Epoch 29/50
#
# Epoch 00029: val_accuracy improved from 0.76031 to 0.79553, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 140s - loss: 0.4726 - accuracy: 0.7799 - val_loss: 0.4516 - val_accuracy: 0.7955 - lr: 0.0010 - 140s/epoch - 498ms/step
# Epoch 30/50
#
# Epoch 00030: val_accuracy improved from 0.79553 to 0.79926, saving model to ./width_model\train.ckpt
# INFO:tensorflow:Assets written to: ./width_model\train.ckpt\assets
# 280/280 - 141s - loss: 0.4590 - accuracy: 0.7865 - val_loss: 0.4375 - val_accuracy: 0.7993 - lr: 0.0010 - 141s/epoch - 505ms/step
# Epoch 31/50
#
# Epoch 00031: val_accuracy did not improve from 0.79926
# 280/280 - 139s - loss: 0.4413 - accuracy: 0.7963 - val_loss: 0.4901 - val_accuracy: 0.7592 - lr: 0.0010 - 139s/epoch - 497ms/step
# Epoch 32/50
#
# Epoch 00032: val_accuracy did not improve from 0.79926
# 280/280 - 139s - loss: 0.4255 - accuracy: 0.8069 - val_loss: 0.4422 - val_accuracy: 0.7932 - lr: 0.0010 - 139s/epoch - 496ms/step
# Epoch 33/50
#
# Epoch 00033: val_accuracy did not improve from 0.79926
# 280/280 - 137s - loss: 0.4083 - accuracy: 0.8178 - val_loss: 0.4685 - val_accuracy: 0.7718 - lr: 0.0010 - 137s/epoch - 491ms/step
# Epoch 34/50
#
# Epoch 00034: val_accuracy did not improve from 0.79926
# 280/280 - 138s - loss: 0.3936 - accuracy: 0.8237 - val_loss: 0.4848 - val_accuracy: 0.7695 - lr: 0.0010 - 138s/epoch - 493ms/step

# %% [markdown]
# Train-Test Accuracy vs Epochs

# %%
plt.figure(figsize=(12,7))
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Width Model - Train-Test Accuracy vs Epochs')
plt.ylabel('Train-Test Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='lower right')
plt.savefig(dir_name + '/train_test_acc.png')
plt.show()

# %% [markdown]
# Train-Val Loss vs Epochs

# %%
plt.figure(figsize=(12,7))
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Width Model - Train-Val Loss vs Epochs')
plt.ylabel('Train-Val Loss')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.savefig(dir_name + '/train_test_loss.png')
plt.show()
