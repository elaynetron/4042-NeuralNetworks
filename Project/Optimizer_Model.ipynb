# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#import os
#os.chdir('/content/drive/MyDrive/Real_data')

# %% [markdown]
# ## Import Libraries

# %%
import os
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pickle5
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load pickle file

# %%
dir_name = './processed/'

def load_pickle(filename):
    with open(dir_name + filename + '.pkl', 'rb') as f:
        return pickle5.load(f)

# %% [markdown]
# ## Initialisation - based on paper

# %%
img_size = 227
num_channels = 3
batch_size = 50
width, height = 256, 256
cropped_width, cropped_height = 227, 227
num_classes = 1

seed = 10
np.random.seed(seed)
tf.random.set_seed(seed)

# Learning rate
lr = 1e-3

# %% [markdown]
# From the paper, it said to drop the learning rate to 1e^-4 when epochs reach 10k.
# (1e^-3 - 1e^-4) is a drop of 10%, hence we use 0.1

# %%
def step_decay(epoch):
    init_lrate = 1e-3
    drop = 0.1
    epochs_drop = 10000
    lrate = init_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

weight_init = keras.initializers.TruncatedNormal(mean=0.0,stddev=0.01,seed=seed)
#bias_init = tf.keras.initializers.Constant(value=0.1)
sgd = keras.optimizers.SGD(learning_rate=lr,momentum=0.0)
loss_func = keras.losses.BinaryCrossentropy()
lrate = keras.callbacks.LearningRateScheduler(step_decay)

# %% [markdown]
# ## Dropout

# %% [markdown]
# Dropouts: 0, 0.2, 0.5, 0.8

# %%
fc1_dropout = 0.8
fc2_dropout = 0.5
fc3_dropout = 0.2

# %% [markdown]
# ## Optimizer & Momentum

# %% [markdown]
# Optimizers: SGD, Adam, RMSProp

# %% [markdown]
# Momentum: 0, 0.3, 0.5, 0.8

# %%
optimizer_name = 'RMSProp'
momentum = 0.3

# %%
if optimizer_name == 'SGD':
    optimizer = keras.optimizers.SGD(learning_rate = lr,momentum = 0.0)
elif optimizer_name == 'SGD-momentum':
    optimizer = keras.optimizers.SGD(learning_rate = lr,momentum = momentum)
elif optimizer_name == 'RMSProp':
    optimizer = keras.optimizers.RMSprop(learning_rate = lr)
elif optimizer_name == 'Adam':
    optimizer = keras.optimizers.Adam(learning_rate = lr)

# %% [markdown]
# ## Load and process data

# %%
to_pickle = [['train', 'test']]
for i in range(5):
  to_pickle.append(["fold_%s_train_sub"%i, "fold_%s_val"%i])

# %%
one_csv = to_pickle[0] # change
train_pickle = load_pickle(one_csv[0])
val_pickle = load_pickle(one_csv[1])

X_train = np.array(train_pickle['images'])    
y_train = np.array(train_pickle['genders'])

X_val = np.array(val_pickle['images'])
y_val = np.array(val_pickle['genders'])

# %% [markdown]
# Check that the image size is as described in the paper (256x256)

# %%
img = X_train[50,:,:,:]
plt.imshow(img)

# %% [markdown]
# Crop image and check that image is now cropped as described in paper (227x227)

# %%
left = int((width - cropped_width)/2)
right = int((width + cropped_width)/2)
top = int((height - cropped_height)/2)
bottom = int((height + cropped_height)/2)

X_train = X_train[:,left:right,top:bottom,:]
X_val = X_val[:,left:right,top:bottom,:]

img = X_train[50,:,:,:]
plt.imshow(img)

# %% [markdown]
# ## Model - based on paper

# %%
model = keras.models.Sequential()
# First convolution layer - 96 filters, 7x7 kernel, 4 strides, valid padding, relu
model.add(keras.layers.Conv2D(96, (7,7),input_shape = (cropped_width, cropped_height, num_channels), strides = 4,
                                  padding ='valid',activation = 'relu',kernel_initializer = weight_init))
# Max pooling - 3x3 kernel, 2 strides, channel last by default
model.add(keras.layers.MaxPool2D(pool_size = (3,3), strides = 2, padding = 'same'))
# Output - 96x28x28
model.add(keras.layers.Lambda(lambda x: tf.nn.local_response_normalization(input=x, alpha=0.0001, beta=0.75)))

# Second convolution layer - 256 filters, 5x5 kernel, relu, same padding
model.add(keras.layers.Conv2D(256, (5,5), padding = 'same',activation = 'relu', kernel_initializer = weight_init))
# Max pooling - 3x3 kernel, 2 strides, channel last by default
model.add(keras.layers.MaxPool2D(pool_size = (3, 3), strides = 2,padding = 'same'))
#Output - 14x14
model.add(keras.layers.Lambda(lambda x: tf.nn.local_response_normalization(input=x, alpha=0.0001, beta=0.75)))\

# Last convolution layer - 384 filters, 3x3 kernel, relu, same padding
model.add(keras.layers.Conv2D(384, (3,3),padding = 'same',activation = 'relu',kernel_initializer = weight_init))
# Max pooling - 3x3 kernel, 2 strides, channel last by default
model.add(keras.layers.MaxPool2D(pool_size = (3,3), strides=2, padding = 'same'))

# Flatten
model.add(keras.layers.Flatten())
# 2 Fully Connected Layers with 512 neurons
# FC1:
model.add(keras.layers.Dropout(fc1_dropout))
model.add(keras.layers.Dense(512,activation = "relu",kernel_initializer = weight_init))
# Dropout
model.add(keras.layers.Dropout(fc2_dropout))
# FC2:
model.add(keras.layers.Dense(512,activation = 'relu',kernel_initializer = weight_init))
#Dropout
model.add(keras.layers.Dropout(fc3_dropout))
#FC3 - Third, fully connected layer which maps to the final classes for age or gender
model.add(keras.layers.Dense(num_classes, activation = 'sigmoid', kernel_initializer = weight_init))

model.compile(loss=loss_func,optimizer=optimizer,metrics=['accuracy'])

dir_name = './optimizer_model/'
if not os.path.isdir(dir_name):
  os.mkdir(dir_name)

checkpoint = keras.callbacks.ModelCheckpoint(dir_name + one_csv[0][:6] + '.ckpt', monitor='val_accuracy', 
                                                 verbose=1, mode='max', save_best_only = True)
csv_logger = keras.callbacks.CSVLogger(dir_name + one_csv[0][:6] + '.csv')
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',patience=4)
callbacks = [lrate,checkpoint,csv_logger,early_stopping]

num_epochs = 50
#if one_csv[0][:4] == 'fold':
#  num_epochs = 500

model.summary()
results = model.fit(X_train, y_train,
                        batch_size = batch_size,
                        epochs = num_epochs,
                        verbose=2,
                        callbacks=callbacks,
                        validation_data = (X_val,y_val))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 56, 56, 96)        14208
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 96)       0
#  2D)
#
#  lambda_2 (Lambda)           (None, 28, 28, 96)        0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 256)       614656
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  lambda_3 (Lambda)           (None, 14, 14, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 384)       885120
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 384)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 18816)             0
#
#  dropout_3 (Dropout)         (None, 18816)             0
#
#  dense_3 (Dense)             (None, 512)               9634304
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 11,411,457
# Trainable params: 11,411,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#
# Epoch 00001: val_accuracy improved from -inf to 0.47738, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 211s - loss: 1.2086 - accuracy: 0.5155 - val_loss: 0.6944 - val_accuracy: 0.4774 - lr: 0.0010 - 211s/epoch - 753ms/step
# Epoch 2/50
#
# Epoch 00002: val_accuracy improved from 0.47738 to 0.52262, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 209s - loss: 0.6981 - accuracy: 0.5312 - val_loss: 0.6873 - val_accuracy: 0.5226 - lr: 0.0010 - 209s/epoch - 746ms/step
# Epoch 3/50
#
# Epoch 00003: val_accuracy improved from 0.52262 to 0.52635, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 207s - loss: 0.6864 - accuracy: 0.5479 - val_loss: 0.7080 - val_accuracy: 0.5263 - lr: 0.0010 - 207s/epoch - 740ms/step
# Epoch 4/50
#
# Epoch 00004: val_accuracy improved from 0.52635 to 0.62199, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 209s - loss: 0.6718 - accuracy: 0.5919 - val_loss: 0.6565 - val_accuracy: 0.6220 - lr: 0.0010 - 209s/epoch - 745ms/step
# Epoch 5/50
#
# Epoch 00005: val_accuracy did not improve from 0.62199
# 280/280 - 211s - loss: 0.6589 - accuracy: 0.6130 - val_loss: 0.7516 - val_accuracy: 0.6048 - lr: 0.0010 - 211s/epoch - 753ms/step
# Epoch 6/50
#
# Epoch 00006: val_accuracy improved from 0.62199 to 0.66008, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 205s - loss: 0.6531 - accuracy: 0.6282 - val_loss: 0.6376 - val_accuracy: 0.6601 - lr: 0.0010 - 205s/epoch - 731ms/step
# Epoch 7/50
#
# Epoch 00007: val_accuracy did not improve from 0.66008
# 280/280 - 207s - loss: 0.6380 - accuracy: 0.6353 - val_loss: 0.6380 - val_accuracy: 0.6094 - lr: 0.0010 - 207s/epoch - 739ms/step
# Epoch 8/50
#
# Epoch 00008: val_accuracy improved from 0.66008 to 0.70418, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 208s - loss: 0.6282 - accuracy: 0.6549 - val_loss: 0.6010 - val_accuracy: 0.7042 - lr: 0.0010 - 208s/epoch - 742ms/step
# Epoch 9/50
#
# Epoch 00009: val_accuracy did not improve from 0.70418
# 280/280 - 214s - loss: 0.6231 - accuracy: 0.6628 - val_loss: 0.6350 - val_accuracy: 0.6859 - lr: 0.0010 - 214s/epoch - 765ms/step
# Epoch 10/50
#
# Epoch 00010: val_accuracy did not improve from 0.70418
# 280/280 - 213s - loss: 0.6102 - accuracy: 0.6705 - val_loss: 0.6186 - val_accuracy: 0.6818 - lr: 0.0010 - 213s/epoch - 762ms/step
# Epoch 11/50
#
# Epoch 00011: val_accuracy did not improve from 0.70418
# 280/280 - 213s - loss: 0.6054 - accuracy: 0.6789 - val_loss: 0.7860 - val_accuracy: 0.6309 - lr: 0.0010 - 213s/epoch - 761ms/step
# Epoch 12/50
#
# Epoch 00012: val_accuracy improved from 0.70418 to 0.71334, saving model to ./optimizer_model\train.ckpt
# INFO:tensorflow:Assets written to: ./optimizer_model\train.ckpt\assets
# 280/280 - 211s - loss: 0.5851 - accuracy: 0.6971 - val_loss: 0.6339 - val_accuracy: 0.7133 - lr: 0.0010 - 211s/epoch - 755ms/step

# %% [markdown]
# Train-Test Accuracy vs Epochs

# %%
plt.figure(figsize=(12,7))
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Optimizer Model - Train-Test Accuracy vs Epochs')
plt.ylabel('Train-Test Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='lower right')
plt.savefig(dir_name + '/train_test_acc.png')
plt.show()

# %% [markdown]
# Train-Val Loss vs Epochs

# %%
plt.figure(figsize=(12,7))
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Optimizer Model - Train-Val Loss vs Epochs')
plt.ylabel('Train-Val Loss')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.savefig(dir_name + '/train_test_loss.png')
plt.show()
